# %% [markdown]
# # Multi-Camera Person Analysis
# This notebook demonstrates how to use the CCTV analysis package for:
# 1. Person detection using YOLOv8x6
# 2. Person re-identification across cameras
# 3. Demographic analysis
# 4. Cross-camera tracking and matching

# %%
from cctv_analysis.person_detector import PersonDetector
from cctv_analysis.reid import PersonReID
from cctv_analysis.demographics import DemographicAnalyzer
from cctv_analysis.matcher import PersonMatcher
import numpy as np
import datetime
import cv2
from pathlib import Path
import sys
import logging
from tqdm.notebook import tqdm

# Add project root to Python path
project_root = Path.cwd().parent
sys.path.append(str(project_root / 'src'))


# Configure logging
logging.basicConfig(level=logging.INFO,
                    format='%(asctime)s - %(levelname)s - %(message)s')
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
def create_id_generator():
    """Creates an infinite ID generator"""
    def infinite_counter():
        counter = 0
        while True:
            yield counter
            counter += 1
    return infinite_counter()


class VideoProcessor:
    def __init__(self, device="cuda"):
        """Initialize all models and components"""
        self.device = device
        self.detector = PersonDetector(device=device)
        self.reid_model = PersonReID(
            model_path=str(project_root / "models/reid/osnet_x1_0.pth"),
            device=device
        )
        self.demographic_analyzer = DemographicAnalyzer(device=device)
        self.matcher = PersonMatcher(
            similarity_threshold=0.5, max_time_diff=3600)
        self.person_id_counter = create_id_generator()

    def process_frame(self, frame, camera_id, timestamp):
        """Process a single frame"""
        if frame is None:
            return []

        # Detect persons
        detections = self.detector.detect(frame, conf_thresh=0.3)

        results = []
        for det in detections:
            try:
                x1, y1, x2, y2, conf = map(int, det)

                # Ensure valid coordinates
                x1, x2 = max(0, x1), min(frame.shape[1], x2)
                y1, y2 = max(0, y1), min(frame.shape[0], y2)

                # Skip if bbox is too small
                if (x2 - x1) < 20 or (y2 - y1) < 20:
                    continue

                # Extract person crop
                person_crop = frame[y1:y2, x1:x2].copy()

                # Extract ReID features
                reid_features = self.reid_model.extract_features(person_crop)

                if reid_features is not None:
                    # Analyze demographics
                    demographics = self.demographic_analyzer.analyze(
                        person_crop)

                    # Generate unique person ID
                    person_id = next(self.person_id_counter)

                    # Add to matcher
                    self.matcher.add_person(
                        camera_id=camera_id,
                        person_id=person_id,
                        timestamp=timestamp,
                        features=reid_features,
                        demographics=demographics[0] if demographics else None
                    )

                    results.append({
                        'id': person_id,
                        'bbox': (x1, y1, x2, y2),
                        'conf': float(conf),
                        'demographics': demographics[0] if demographics else None
                    })

            except Exception as e:
                logging.error(f"Error processing detection: {e}")
                continue

        return results

    def process_video(self, video_path, camera_id, start_time, display=True, skip_frames=5):
        """Process entire video"""
        cap = cv2.VideoCapture(str(video_path))
        if not cap.isOpened():
            raise ValueError(f"Could not open video: {video_path}")

        total_frames = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
        fps = cap.get(cv2.CAP_PROP_FPS)
        frame_count = 0

        logging.info(f"Processing video {video_path}")
        logging.info(f"Total frames: {total_frames}, FPS: {fps}")

        # Create progress bar
        pbar = tqdm(total=total_frames // skip_frames,
                    desc=f"Camera {camera_id}")

        try:
            while cap.isOpened():
                ret, frame = cap.read()
                if not ret:
                    break

                # Process every nth frame
                if frame_count % skip_frames == 0:
                    # Calculate timestamp
                    timestamp = start_time + \
                        datetime.timedelta(seconds=frame_count/fps)

                    # Process frame
                    results = self.process_frame(frame, camera_id, timestamp)

                    # Visualize results
                    if display and results:
                        frame = self.draw_results(frame, results)
                        cv2.imshow(f'Camera {camera_id}', frame)
                        if cv2.waitKey(1) & 0xFF == ord('q'):
                            break

                    pbar.update(1)

                frame_count += 1

        except Exception as e:
            logging.error(f"Error processing video: {e}")
            raise

        finally:
            cap.release()
            pbar.close()

    def draw_results(self, frame, results):
        """Draw detection results on frame"""
        for person in results:
            x1, y1, x2, y2 = person['bbox']
            # Draw bounding box
            cv2.rectangle(frame, (x1, y1), (x2, y2), (0, 255, 0), 2)

            # Prepare label text
            label = f"ID: {person['id']}"
            if person['demographics']:
                demo = person['demographics']
                label += f" | {demo['gender']} | {demo['age_group']}"

            # Draw label
            cv2.putText(frame, label, (x1, y1-10),
                        cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 0), 2)

        return frame

    def analyze_results(self):
        """Print analysis results"""
        self.matcher.print_matching_stats()
        self.matcher.visualize_matches(n_samples=5)

# %%
# Initialize video processor
processor = VideoProcessor(device="cuda")

# Define start times for both videos
start_time_1 = datetime.datetime(2024, 1, 1, 12, 0, 0)
start_time_2 = datetime.datetime(2024, 1, 1, 12, 0, 30)  # 30 seconds later

# Process videos
try:
    processor.process_video(
        video_path=project_root / 'data/processed_data/D04_20241108.mp4',
        camera_id=2,
        start_time=start_time_1
    )

    processor.process_video(
        video_path=project_root / 'data/processed_data/D10_20241108.mp4',
        camera_id=1,
        start_time=start_time_2
    )

finally:
    cv2.destroyAllWindows()
# Out:
# Using GPU: NVIDIA T1000 8GB
# GPU Memory Available: 8.00 GB
# Successfully loaded YOLOv8x6 model
# Using GPU: NVIDIA T1000 8GB
# Successfully loaded pretrained weights from c:\GitHub\cctv-analysis\models\reid\osnet_x1_0.pth
# Using CUDA for demographic analysis
# Applied providers: ['CPUExecutionProvider'], with options: {'CPUExecutionProvider': {}}
# model ignore: C:\Users\mc1159\.insightface/models\models\buffalo_l\1k3d68.onnx landmark_3d_68
# Applied providers: ['CPUExecutionProvider'], with options: {'CPUExecutionProvider': {}}
# model ignore: C:\Users\mc1159\.insightface/models\models\buffalo_l\2d106det.onnx landmark_2d_106
# Applied providers: ['CPUExecutionProvider'], with options: {'CPUExecutionProvider': {}}
# find model: C:\Users\mc1159\.insightface/models\models\buffalo_l\det_10g.onnx detection [1, 3, '?', '?'] 127.5 128.0
# Applied providers: ['CPUExecutionProvider'], with options: {'CPUExecutionProvider': {}}
# find model: C:\Users\mc1159\.insightface/models\models\buffalo_l\genderage.onnx genderage ['None', 3, 96, 96] 0.0 1.0
# Applied providers: ['CPUExecutionProvider'], with options: {'CPUExecutionProvider': {}}
# model ignore: C:\Users\mc1159\.insightface/models\models\buffalo_l\w600k_r50.onnx recognition
# Error during model initialization: prepare() got an unexpected keyword argument 'det_scale'
# Attempting manual model initialization...
# Manual model initialization successful
# 2024-11-20 11:12:55,514 - INFO - Processing video c:\GitHub\cctv-analysis\data\processed_data\D04_20241108.mp4
# 2024-11-20 11:12:55,516 - INFO - Total frames: 43504, FPS: 6.0
# Camera 2:   0%|          | 0/8700 [00:00<?, ?it/s]
# 0: 768x1280 (no detections), 4323.1ms
# Speed: 23.9ms preprocess, 4323.1ms inference, 61.9ms postprocess per image at shape (1, 3, 768, 1280)
#
# 0: 768x1280 (no detections), 248.3ms
# Speed: 12.0ms preprocess, 248.3ms inference, 85.7ms postprocess per image at shape (1, 3, 768, 1280)
#
# 0: 768x1280 (no detections), 248.9ms
# Speed: 10.0ms preprocess, 248.9ms inference, 5.0ms postprocess per image at shape (1, 3, 768, 1280)
#
# 0: 768x1280 (no detections), 248.5ms
# Speed: 9.0ms preprocess, 248.5ms inference, 2.0ms postprocess per image at shape (1, 3, 768, 1280)
#
# 0: 768x1280 (no detections), 249.6ms
# Speed: 9.0ms preprocess, 249.6ms inference, 4.6ms postprocess per image at shape (1, 3, 768, 1280)
#
# 0: 768x1280 (no detections), 247.4ms
# Speed: 9.0ms preprocess, 247.4ms inference, 5.0ms postprocess per image at shape (1, 3, 768, 1280)
#
# 0: 768x1280 (no detections), 245.3ms
# Speed: 12.1ms preprocess, 245.3ms inference, 4.1ms postprocess per image at shape (1, 3, 768, 1280)
#
# 0: 768x1280 (no detections), 250.0ms
# Speed: 11.0ms preprocess, 250.0ms inference, 5.0ms postprocess per image at shape (1, 3, 768, 1280)
#
# 0: 768x1280 (no detections), 249.9ms
# Speed: 16.0ms preprocess, 249.9ms inference, 3.0ms postprocess per image at shape (1, 3, 768, 1280)
#
# 0: 768x1280 (no detections), 248.2ms
# Speed: 11.0ms preprocess, 248.2ms inference, 3.0ms postprocess per image at shape (1, 3, 768, 1280)
#
# 0: 768x1280 (no detections), 248
3ms postprocess per image at shape (1, 3, 768, 1280)
#
# 0: 768x1280 (no detections), 265.7ms
# Speed: 5.7ms preprocess, 265.7ms inference, 0.0ms postprocess per image at shape (1, 3, 768, 1280)
#
# 0: 768x1280 (no detections), 262.0ms
# Speed: 11.7ms preprocess, 262.0ms inference, 0.0ms postprocess per image at shape (1, 3, 768, 1280)
#
# 0: 768x1280 (no detections), 263.2ms
# Speed: 13.6ms preprocess, 263.2ms inference, 1.1ms postprocess per image at shape (1, 3, 768, 1280)
#
# 0: 768x1280 (no detections), 260.5ms
# Speed: 14.2ms preprocess, 260.5ms inference, 0.0ms postprocess per image at shape (1, 3, 768, 1280)
#
# 0: 768x1280 (no detections), 253.5ms
# Speed: 18.5ms preprocess, 253.5ms inference, 0.0ms postprocess per image at shape (1, 3, 768, 1280)
#
# 0: 768x1280 (no detections), 261.2ms
# Speed: 13.1ms preprocess, 261.2ms inference, 3.0ms postprocess per image at shape (1, 3, 768, 1280)
#
# 0: 768x1280 (no detections), 260.9ms
# Speed: 13.0ms preprocess, 260.9ms inference, 2.0ms postprocess per image at shape (1, 3, 768, 1280)
#
# 0: 768x1280 (no detections), 268.7ms
# Speed: 0.0ms preprocess, 268.7ms inference, 0.0ms postprocess per image at shape (1, 3, 768, 1280)
#
# 0: 768x1280 (no detections), 262.0ms
# Speed: 9.7ms preprocess, 262.0ms inference, 3.0ms postprocess per image at shape (1, 3, 768, 1280)
#
# 0: 768x1280 (no detections), 263.1ms
# Speed: 14.0ms preprocess, 263.1ms inference, 3.0ms postprocess per image at shape (1, 3, 768, 1280)
#
# 0: 768x1280 (no detections), 259.9ms
# Speed: 11.2ms preprocess, 259.9ms inference, 4.0ms postprocess per image at shape (1, 3, 768, 1280)
#
# 0: 768x1280 (no detections), 258.5ms
# Speed: 13.0ms preprocess, 258.5ms inference, 0.0ms postprocess per image at shape (1, 3, 768, 1280)
#
# 0: 768x1280 (no detections), 245.3ms
# Speed: 10.3ms preprocess, 245.3ms inference, 15.5ms postprocess per image at shape (1, 3, 768, 1280)
#
# 0: 768x1280 (no detections), 246.6ms
# Speed: 9.0ms preprocess, 246.6ms inference, 15.1ms postprocess per image at shape (1, 3, 768, 1280)
#
# 0: 768x1280 (no detections), 247.6ms
# Speed: 9.4ms preprocess, 247.6ms inference, 0.0ms postprocess per image at shape (1, 3, 768, 1280)
#
# 0: 768x1280 (no detections), 249.6ms
# Speed: 10.5ms preprocess, 249.6ms inference, 0.0ms postprocess per image at shape (1, 3, 768, 1280)
#
# 0: 768x1280 (no detections), 263.6ms
# Speed: 1.2ms preprocess, 263.6ms inference, 3.0ms postprocess per image at shape (1, 3, 768, 1280)
#
# 0: 768x1280 (no detections), 258.2ms
# Speed: 13.0ms preprocess, 258.2ms inference, 3.2ms postprocess per image at shape (1, 3, 768, 1280)
#
# 0: 768x1280 (no detections), 243.3ms
# Speed: 11.9ms preprocess, 243.3ms inference, 16.2ms postprocess per image at shape (1, 3, 768, 1280)
#
# 0: 768x1280 (no detections), 256.7ms
# Speed: 10.1ms preprocess, 256.7ms inference, 2.0ms postprocess per image at shape (1, 3, 768, 1280)
#
# 0: 768x1280 (no detections), 260.9ms
# Speed: 20.2ms preprocess, 260.9ms inference, 3.3ms postprocess per image at shape (1, 3, 768, 1280)
#
# 0: 768x1280 (no detections), 270.2ms
# Speed: 12.9ms preprocess, 270.2ms inference, 2.3ms postprocess per image at shape (1, 3, 768, 1280)
#
# 0: 768x1280 (no detections), 260.4ms
# Speed: 11.6ms preprocess, 260.4ms inference, 3.0ms postprocess per image at shape (1, 3, 768, 1280)
#
# 0: 768x1280 (no detections), 255.8ms
# Speed: 13.6ms preprocess, 255.8ms inference, 8.8ms postprocess per image at shape (1, 3, 768, 1280)
#
# 0: 768x1280 (no detections), 260.2ms
# Speed: 10.4ms preprocess, 260.2ms inference, 0.0ms postprocess per image at shape (1, 3, 768, 1280)
#
# 0: 768x1280 (no detections), 259.6ms
# Speed: 13.7ms preprocess, 259.6ms inference, 2.5ms postprocess per image at shape (1, 3, 768, 1280)
#
# 0: 768x1280 (no detections), 251.0ms
# Speed: 12.8ms preprocess, 251.0ms inference, 0.0ms postprocess per image at shape (1, 3, 768, 1280)
#
# 0: 768x1280 1 person, 253.0ms
# Speed: 10.3ms preprocess, 253.0ms inference, 15.0ms postprocess per image at shape (1, 3, 768, 1280)
# Error in face detection at scale 0.9:
# Error in face detection at scale 1.0:
# Error in face detection at scale 1.1:
#
# 0: 768x1280 1 person, 253.4ms
# Speed: 5.5ms preprocess, 253.4ms inference, 0.0ms postprocess per image at shape (1, 3, 768, 1280)
# Error in face detection at scale 0.9:
# Error in face detection at scale 1.0:
# Error in face detection at scale 1.1:
#
# 0: 768x1280 1 person, 267.4ms
# Speed: 15.6ms preprocess, 267.4ms inference, 5.6ms postprocess per image at shape (1, 3, 768, 1280)
# Error in face detection at scale 0.9:
# Error in face detection at scale 1.0:
# Error in face detection at scale 1.1:
#
# 0: 768x1280 1 person, 251.3ms
# Speed: 18.6ms preprocess, 251.3ms inference, 0.0ms postprocess per image at shape (1, 3, 768, 1280)
# Error in face detection at scale 0.9:
# Error in face detection at scale 1.0:
# Error in face detection at scale 1.1:
#
# 0: 768x1280 1 person, 249.0ms
# Speed: 9.0ms preprocess, 249.0ms inference, 14.5ms postprocess per image at shape (1, 3, 768, 1280)
# Error in face detection at scale 0.9:
# Error in face detection at scale 1.0:
# Error in face detection at scale 1.1:
#
# 0: 768x1280 1 person, 257.5ms
# Speed: 8.7ms preprocess, 257.5ms inference, 0.0ms postprocess per image at shape (1, 3, 768, 1280)
# Error in face detection at scale 0.9:
# Error in face detection at scale 1.0:
# Error in face detection at scale 1.1:
#
# 0: 768x1280 1 person, 263.4ms
# Speed: 9.4ms preprocess, 263.4ms inference, 3.8ms postprocess per image at shape (1, 3, 768, 1280)
# Error in face detection at scale 0.9:
# Error in face detection at scale 1.0:
# Error in face detection at scale 1.1:
#
# 0: 768x1280 1 person, 255.5ms
# Speed: 12.0ms preprocess, 255.5ms inference, 7.0ms postprocess per image at shape (1, 3, 768, 1280)
# Error in face detection at scale 0.9:
# Error in face detection at scale 1.0:
# Error in face detection at scale 1.1:
#
# 0: 768x1280 1 person, 254.4ms
# Speed: 10.0ms preprocess, 254.4ms inference, 4.5ms postprocess per image at shape (1, 3, 768, 1280)
# Error in face detection at scale 0.9:
# Error in face detection at scale 1.0:
# Error in face detection at scale 1.1:
#
# 0: 768x1280 1 person, 256.3ms
# Speed: 11.1ms preprocess, 256.3ms inference, 5.1ms postprocess per image at shape (1, 3, 768, 1280)
# Error in face detection at scale 0.9:
# Error in face detection at scale 1.0:
# Error in face detection at scale 1.1:
#
# 0: 768x1280 1 person, 256.5ms
# Speed: 9.0ms preprocess, 256.5ms inference, 3.1ms postprocess per image at shape (1, 3, 768, 1280)
# Error in face detection at scale 0.9:
# Error in face detection at scale 1.0:
# Error in face detection at scale 1.1:
#
# 0: 768x1280 1 person, 256.4ms
# Speed: 11.0ms preprocess, 256.4ms inference, 5.8ms postprocess per image at shape (1, 3, 768, 1280)
# Error in face detection at scale 0.9:
# Error in face detection at scale 1.0:
# Error in face detection at scale 1.1:
#
# 0: 768x1280 2 persons, 264.9ms
# Speed: 0.0ms preprocess, 264.9ms inference, 2.8ms postprocess per image at shape (1, 3, 768, 1280)

# %%
# Analyze results
processor.analyze_results()
