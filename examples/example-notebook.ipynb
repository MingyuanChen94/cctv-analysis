# %% [markdown]
# # Multi-Camera Person Analysis
# This notebook demonstrates how to use the CCTV analysis package for:
# 1. Person detection using YOLOv8x6
# 2. Person re-identification across cameras
# 3. Demographic analysis
# 4. Cross-camera tracking and matching

# %%
from cctv_analysis.person_detector import PersonDetector
from cctv_analysis.reid import PersonReID
from cctv_analysis.demographics import DemographicAnalyzer
from cctv_analysis.matcher import PersonMatcher
import numpy as np
import datetime
import cv2
from pathlib import Path
import sys
import logging
from tqdm.notebook import tqdm

# Add project root to Python path
project_root = Path.cwd().parent
sys.path.append(str(project_root / 'src'))


# Configure logging
logging.basicConfig(level=logging.INFO,
                    format='%(asctime)s - %(levelname)s - %(message)s')
# Out:
# c:\Users\mc1159\AppData\Local\anaconda3\envs\cctv-analysis\lib\site-packages\albumentations\__init__.py:13: UserWarning: A new version of Albumentations is available: 1.4.21 (you have 1.4.18). Upgrade using: pip install -U albumentations. To disable automatic update checks, set the environment variable NO_ALBUMENTATIONS_UPDATE to 1.
#   check_for_updates()

# %%
def create_id_generator():
    """Creates an infinite ID generator"""
    def infinite_counter():
        counter = 0
        while True:
            yield counter
            counter += 1
    return infinite_counter()


class VideoProcessor:
    def __init__(self, device="cuda"):
        """Initialize all models and components"""
        self.device = device
        self.detector = PersonDetector(device=device)
        self.reid_model = PersonReID(
            model_path=str(project_root / "models/reid/osnet_x1_0.pth"),
            device=device
        )
        self.demographic_analyzer = DemographicAnalyzer(device=device)
        self.matcher = PersonMatcher(
            similarity_threshold=0.5, max_time_diff=3600)
        self.person_id_counter = create_id_generator()

    def process_frame(self, frame, camera_id, timestamp):
        """Process a single frame"""
        if frame is None:
            return []

        # Detect persons
        detections = self.detector.detect(frame, conf_thresh=0.3)

        results = []
        for det in detections:
            try:
                x1, y1, x2, y2, conf = map(int, det)

                # Ensure valid coordinates
                x1, x2 = max(0, x1), min(frame.shape[1], x2)
                y1, y2 = max(0, y1), min(frame.shape[0], y2)

                # Skip if bbox is too small
                if (x2 - x1) < 20 or (y2 - y1) < 20:
                    continue

                # Extract person crop
                person_crop = frame[y1:y2, x1:x2].copy()

                # Extract ReID features
                reid_features = self.reid_model.extract_features(person_crop)

                if reid_features is not None:
                    # Analyze demographics
                    demographics = self.demographic_analyzer.analyze(
                        person_crop)

                    # Generate unique person ID
                    person_id = next(self.person_id_counter)

                    # Add to matcher
                    self.matcher.add_person(
                        camera_id=camera_id,
                        person_id=person_id,
                        timestamp=timestamp,
                        features=reid_features,
                        demographics=demographics[0] if demographics else None
                    )

                    results.append({
                        'id': person_id,
                        'bbox': (x1, y1, x2, y2),
                        'conf': float(conf),
                        'demographics': demographics[0] if demographics else None
                    })

            except Exception as e:
                logging.error(f"Error processing detection: {e}")
                continue

        return results

    def process_video(self, video_path, camera_id, start_time, display=True, skip_frames=5):
        """Process entire video"""
        cap = cv2.VideoCapture(str(video_path))
        if not cap.isOpened():
            raise ValueError(f"Could not open video: {video_path}")

        total_frames = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
        fps = cap.get(cv2.CAP_PROP_FPS)
        frame_count = 0

        logging.info(f"Processing video {video_path}")
        logging.info(f"Total frames: {total_frames}, FPS: {fps}")

        # Create progress bar
        pbar = tqdm(total=total_frames // skip_frames,
                    desc=f"Camera {camera_id}")

        try:
            while cap.isOpened():
                ret, frame = cap.read()
                if not ret:
                    break

                # Process every nth frame
                if frame_count % skip_frames == 0:
                    # Calculate timestamp
                    timestamp = start_time + \
                        datetime.timedelta(seconds=frame_count/fps)

                    # Process frame
                    results = self.process_frame(frame, camera_id, timestamp)

                    # Visualize results
                    if display and results:
                        frame = self.draw_results(frame, results)
                        cv2.imshow(f'Camera {camera_id}', frame)
                        if cv2.waitKey(1) & 0xFF == ord('q'):
                            break

                    pbar.update(1)

                frame_count += 1

        except Exception as e:
            logging.error(f"Error processing video: {e}")
            raise

        finally:
            cap.release()
            pbar.close()

    def draw_results(self, frame, results):
        """Draw detection results on frame"""
        for person in results:
            x1, y1, x2, y2 = person['bbox']
            # Draw bounding box
            cv2.rectangle(frame, (x1, y1), (x2, y2), (0, 255, 0), 2)

            # Prepare label text
            label = f"ID: {person['id']}"
            if person['demographics']:
                demo = person['demographics']
                label += f" | {demo['gender']} | {demo['age_group']}"

            # Draw label
            cv2.putText(frame, label, (x1, y1-10),
                        cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 0), 2)

        return frame

    def analyze_results(self):
        """Print analysis results"""
        self.matcher.print_matching_stats()
        self.matcher.visualize_matches(n_samples=5)

# %%
# Initialize video processor
processor = VideoProcessor(device="cuda")

# Define start times for both videos
start_time_1 = datetime.datetime(2024, 1, 1, 12, 0, 0)
start_time_2 = datetime.datetime(2024, 1, 1, 12, 0, 30)  # 30 seconds later

# Process videos
try:
    processor.process_video(
        video_path=project_root / 'data/processed_data/D10_20241108.mp4',
        camera_id=1,
        start_time=start_time_2
    )

    processor.process_video(
        video_path=project_root / 'data/processed_data/D04_20241108.mp4',
        camera_id=2,
        start_time=start_time_1
    )

finally:
    cv2.destroyAllWindows()
# Out:
# Using GPU: NVIDIA T1000 8GB
# GPU Memory Available: 8.00 GB
# Successfully loaded YOLOv8x6 model
# Using GPU: NVIDIA T1000 8GB
# Successfully loaded pretrained weights from c:\GitHub\cctv-analysis\models\reid\osnet_x1_0.pth
# Using CUDA for demographic analysis
# Applied providers: ['CPUExecutionProvider'], with options: {'CPUExecutionProvider': {}}
# model ignore: C:\Users\mc1159\.insightface/models\models\buffalo_l\1k3d68.onnx landmark_3d_68
# Applied providers: ['CPUExecutionProvider'], with options: {'CPUExecutionProvider': {}}
# model ignore: C:\Users\mc1159\.insightface/models\models\buffalo_l\2d106det.onnx landmark_2d_106
# Applied providers: ['CPUExecutionProvider'], with options: {'CPUExecutionProvider': {}}
# find model: C:\Users\mc1159\.insightface/models\models\buffalo_l\det_10g.onnx detection [1, 3, '?', '?'] 127.5 128.0
# Applied providers: ['CPUExecutionProvider'], with options: {'CPUExecutionProvider': {}}
# find model: C:\Users\mc1159\.insightface/models\models\buffalo_l\genderage.onnx genderage ['None', 3, 96, 96] 0.0 1.0
# Applied providers: ['CPUExecutionProvider'], with options: {'CPUExecutionProvider': {}}
# model ignore: C:\Users\mc1159\.insightface/models\models\buffalo_l\w600k_r50.onnx recognition
# 2024-11-13 21:00:49,768 - INFO - Processing video c:\GitHub\cctv-analysis\data\processed_data\D04_20241108.mp4
# 2024-11-13 21:00:49,777 - INFO - Total frames: 43504, FPS: 6.0
# set det-size: (640, 640)
# Model preparation successful
# Camera 2:   0%|          | 0/8700 [00:00<?, ?it/s]
# 0: 768x1280 (no detections), 4160.6ms
# Speed: 5.8ms preprocess, 4160.6ms inference, 69.8ms postprocess per image at shape (1, 3, 768, 1280)
#
# 0: 768x1280 (no detections), 258.9ms
# Speed: 3.4ms preprocess, 258.9ms inference, 41.9ms postprocess per image at shape (1, 3, 768, 1280)
#
# 0: 768x1280 (no detections), 250.0ms
# Speed: 12.5ms preprocess, 250.0ms inference, 2.0ms postprocess per image at shape (1, 3, 768, 1280)
#
# 0: 768x1280 (no detections), 252.6ms
# Speed: 6.6ms preprocess, 252.6ms inference, 2.5ms postprocess per image at shape (1, 3, 768, 1280)
#
# 0: 768x1280 (no detections), 249.3ms
# Speed: 15.8ms preprocess, 249.3ms inference, 0.0ms postprocess per image at shape (1, 3, 768, 1280)
#
# 0: 768x1280 (no detections), 242.6ms
# Speed: 17.0ms preprocess, 242.6ms inference, 0.0ms postprocess per image at shape (1, 3, 768, 1280)
#
# 0: 768x1280 (no detections), 239.9ms
# Speed: 8.8ms preprocess, 239.9ms inference, 0.0ms postprocess per image at shape (1, 3, 768, 1280)
#
# 0: 768x1280 (no detections), 248.5ms
# Speed: 8.2ms preprocess, 248.5ms inference, 0.0ms postprocess per image at shape (1, 3, 768, 1280)
#
# 0: 768x1280 (no detections), 243.2ms
# Speed: 4.5ms preprocess, 243.2ms inference, 0.0ms postprocess per image at shape (1, 3, 768, 1280)
#
# 0: 768x1280 (no detections), 240.7ms
# Speed: 14.9ms preprocess, 240.7ms inference, 0.0ms postprocess per image at shape (1, 3, 768, 1280)
#
# 0: 768x1280 (no detections), 245.4ms
# Speed: 24.8ms preprocess, 245.4ms inference, 0.0ms postprocess per image at shape (1, 3, 768, 1280)
#
# 0: 768x1280 (no detections), 238.7ms
# Speed: 8.0ms preprocess, 238.7ms inference, 15.6ms postprocess per image at shape (1, 3, 768, 1280)
#
# 0: 768x1280 (no detections), 245.1ms
# Speed: 13.0ms preprocess, 245.1ms inference, 0.0ms postprocess per image at shape (1, 3, 768, 1280)
#
# 0: 768x1280 (no detections), 247.9ms
# Speed: 13.4ms preprocess, 247.9ms inference, 0.0ms postprocess per image at shape (1, 3, 768, 1280)
#
# 0: 768x1280 (no detections), 242.5ms
# Speed: 10.7ms preprocess, 242.5ms inference, 0.0ms postprocess per image at shape (1, 3, 768, 1280)
#
# 0: 768x1280 (no detections), 250.6ms
# Speed: 4.9ms preprocess, 250.6ms inference, 0.0ms postprocess per image at shape (1, 3, 768, 1280)
#
# 0: 768x1280 (no detections), 244.2ms
# Speed: 20.3ms preprocess, 244.2ms inference, 0.0ms postprocess per image at shape (1, 3, 768, 1280)
#
# 0: 768x1280 (no detections), 248.9ms
# Speed: 15.7ms preprocess, 248.9ms inference, 0.0ms postprocess per image at shape (1, 3, 768, 1280)
#
# 0: 768x1280 (no detections), 249
ms inference, 3.0ms postprocess per image at shape (1, 3, 768, 1280)
#
# 0: 768x1280 10 persons, 247.1ms
# Speed: 9.0ms preprocess, 247.1ms inference, 7.0ms postprocess per image at shape (1, 3, 768, 1280)
#
# 0: 768x1280 9 persons, 249.1ms
# Speed: 9.0ms preprocess, 249.1ms inference, 3.0ms postprocess per image at shape (1, 3, 768, 1280)
#
# 0: 768x1280 11 persons, 247.5ms
# Speed: 8.0ms preprocess, 247.5ms inference, 5.1ms postprocess per image at shape (1, 3, 768, 1280)
#
# 0: 768x1280 11 persons, 248.1ms
# Speed: 9.0ms preprocess, 248.1ms inference, 7.0ms postprocess per image at shape (1, 3, 768, 1280)
#
# 0: 768x1280 13 persons, 248.7ms
# Speed: 9.1ms preprocess, 248.7ms inference, 6.0ms postprocess per image at shape (1, 3, 768, 1280)
#
# 0: 768x1280 14 persons, 382.0ms
# Speed: 8.1ms preprocess, 382.0ms inference, 6.3ms postprocess per image at shape (1, 3, 768, 1280)
#
# 0: 768x1280 11 persons, 375.5ms
# Speed: 9.0ms preprocess, 375.5ms inference, 7.0ms postprocess per image at shape (1, 3, 768, 1280)
#
# 0: 768x1280 11 persons, 249.1ms
# Speed: 9.1ms preprocess, 249.1ms inference, 6.0ms postprocess per image at shape (1, 3, 768, 1280)
#
# 0: 768x1280 14 persons, 248.1ms
# Speed: 11.0ms preprocess, 248.1ms inference, 7.1ms postprocess per image at shape (1, 3, 768, 1280)
#
# 0: 768x1280 13 persons, 372.7ms
# Speed: 10.6ms preprocess, 372.7ms inference, 4.0ms postprocess per image at shape (1, 3, 768, 1280)
#
# 0: 768x1280 11 persons, 386.8ms
# Speed: 8.1ms preprocess, 386.8ms inference, 6.0ms postprocess per image at shape (1, 3, 768, 1280)
#
# 0: 768x1280 12 persons, 248.3ms
# Speed: 11.1ms preprocess, 248.3ms inference, 4.1ms postprocess per image at shape (1, 3, 768, 1280)
#
# 0: 768x1280 13 persons, 354.9ms
# Speed: 8.0ms preprocess, 354.9ms inference, 4.0ms postprocess per image at shape (1, 3, 768, 1280)
#
# 0: 768x1280 13 persons, 393.1ms
# Speed: 9.1ms preprocess, 393.1ms inference, 3.0ms postprocess per image at shape (1, 3, 768, 1280)
#
# 0: 768x1280 12 persons, 353.0ms
# Speed: 7.5ms preprocess, 353.0ms inference, 7.0ms postprocess per image at shape (1, 3, 768, 1280)
#
# 0: 768x1280 13 persons, 360.8ms
# Speed: 9.0ms preprocess, 360.8ms inference, 5.2ms postprocess per image at shape (1, 3, 768, 1280)
#
# 0: 768x1280 13 persons, 395.0ms
# Speed: 9.0ms preprocess, 395.0ms inference, 4.0ms postprocess per image at shape (1, 3, 768, 1280)
#
# 0: 768x1280 12 persons, 370.3ms
# Speed: 8.1ms preprocess, 370.3ms inference, 5.1ms postprocess per image at shape (1, 3, 768, 1280)
#
# 0: 768x1280 13 persons, 375.7ms
# Speed: 8.0ms preprocess, 375.7ms inference, 7.0ms postprocess per image at shape (1, 3, 768, 1280)
#
# 0: 768x1280 15 persons, 370.4ms
# Speed: 9.1ms preprocess, 370.4ms inference, 7.0ms postprocess per image at shape (1, 3, 768, 1280)
#
# 0: 768x1280 13 persons, 402.2ms
# Speed: 11.1ms preprocess, 402.2ms inference, 6.1ms postprocess per image at shape (1, 3, 768, 1280)
#
# 0: 768x1280 13 persons, 359.3ms
# Speed: 9.0ms preprocess, 359.3ms inference, 3.0ms postprocess per image at shape (1, 3, 768, 1280)
#
# 0: 768x1280 13 persons, 387.7ms
# Speed: 10.1ms preprocess, 387.7ms inference, 4.1ms postprocess per image at shape (1, 3, 768, 1280)
#
# 0: 768x1280 12 persons, 358.5ms
# Speed: 12.1ms preprocess, 358.5ms inference, 6.0ms postprocess per image at shape (1, 3, 768, 1280)
#
# 0: 768x1280 14 persons, 356.2ms
# Speed: 8.1ms preprocess, 356.2ms inference, 7.0ms postprocess per image at shape (1, 3, 768, 1280)
#
# 0: 768x1280 12 persons, 389.4ms
# Speed: 9.0ms preprocess, 389.4ms inference, 6.0ms postprocess per image at shape (1, 3, 768, 1280)
#
# 0: 768x1280 11 persons, 367.4ms
# Speed: 8.0ms preprocess, 367.4ms inference, 6.0ms postprocess per image at shape (1, 3, 768, 1280)
#
# 0: 768x1280 11 persons, 247.2ms
# Speed: 10.0ms preprocess, 247.2ms inference, 6.5ms postprocess per image at shape (1, 3, 768, 1280)
#
# 0: 768x1280 13 persons, 247.8ms
# Speed: 9.0ms preprocess, 247.8ms inference, 6.0ms postprocess per image at shape (1, 3, 768, 1280)
#
# 0: 768x1280 12 persons, 382.8ms
# Speed: 9.0ms preprocess, 382.8ms inference, 4.0ms postprocess per image at shape (1, 3, 768, 1280)
#
# 0: 768x1280 12 persons, 363.5ms
# Speed: 11.1ms preprocess, 363.5ms inference, 7.0ms postprocess per image at shape (1, 3, 768, 1280)
#
# 0: 768x1280 14 persons, 246.8ms
# Speed: 8.0ms preprocess, 246.8ms inference, 7.0ms postprocess per image at shape (1, 3, 768, 1280)
#
# 0: 768x1280 12 persons, 400.2ms
# Speed: 8.6ms preprocess, 400.2ms inference, 7.2ms postprocess per image at shape (1, 3, 768, 1280)
#
# 0: 768x1280 12 persons, 258.7ms
# Speed: 9.1ms preprocess, 258.7ms inference, 4.1ms postprocess per image at shape (1, 3, 768, 1280)
#
# 0: 768x1280 11 persons, 377.2ms
# Speed: 9.0ms preprocess, 377.2ms inference, 6.7ms postprocess per image at shape (1, 3, 768, 1280)
#
# 0: 768x1280 11 persons, 347.7ms
# Speed: 9.0ms preprocess, 347.7ms inference, 6.0ms postprocess per image at shape (1, 3, 768, 1280)
#
# 0: 768x1280 12 persons, 246.7ms
# Speed: 9.0ms preprocess, 246.7ms inference, 6.0ms postprocess per image at shape (1, 3, 768, 1280)
#
# 0: 768x1280 12 persons, 247.1ms
# Speed: 10.1ms preprocess, 247.1ms inference, 3.0ms postprocess per image at shape (1, 3, 768, 1280)
#
# 0: 768x1280 9 persons, 361.0ms
# Speed: 9.0ms preprocess, 361.0ms inference, 3.0ms postprocess per image at shape (1, 3, 768, 1280)
#
# 0: 768x1280 10 persons, 248.7ms
# Speed: 9.0ms preprocess, 248.7ms inference, 6.1ms postprocess per image at shape (1, 3, 768, 1280)
#
# 0: 768x1280 13 persons, 248.4ms
# Speed: 9.1ms preprocess, 248.4ms inference, 3.0ms postprocess per image at shape (1, 3, 768, 1280)
#
# 0: 768x1280 13 persons, 400.2ms
# Speed: 10.1ms preprocess, 400.2ms inference, 6.0ms postprocess per image at shape (1, 3, 768, 1280)
#
# 0: 768x1280 12 persons, 384.1ms
# Speed: 8.1ms preprocess, 384.1ms inference, 3.0ms postprocess per image at shape (1, 3, 768, 1280)
#
# 0: 768x1280 11 persons, 392.3ms
# Speed: 10.0ms preprocess, 392.3ms inference, 3.0ms postprocess per image at shape (1, 3, 768, 1280)
#
# 0: 768x1280 15 persons, 248.1ms
# Speed: 8.1ms preprocess, 248.1ms inference, 3.0ms postprocess per image at shape (1, 3, 768, 1280)
#
# 0: 768x1280 11 persons, 401.5ms
# Speed: 9.0ms preprocess, 401.5ms inference, 7.1ms postprocess per image at shape (1, 3, 768, 1280)
#
# 0: 768x1280 11 persons, 248.2ms
# Speed: 8.0ms preprocess, 248.2ms inference, 3.0ms postprocess per image at shape (1, 3, 768, 1280)

# %%
# Analyze results
processor.analyze_results()
# Out:
# Matching Statistics:
# Number of people detected in Camera 1: 73275
# Number of people detected in Camera 2: 18987
# Number of matches found: 0
# No matches to visualize
